# %% [markdown]
# # RAG Debugging Notebook
#
# This notebook is for debugging and testing RAG functionality.

# %%
# Import necessary modules
import sys
import os
sys.path.append('../src')

from llm.graphrag import *
from backends.fastapi_app import *

# %%
# Test RAG functionality
print("RAG debugging notebook ready!")
