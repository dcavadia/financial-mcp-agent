# %% [markdown]
# # Prompt Development Notebook
#
# This notebook is for developing and testing prompt templates.

# %%
# Import necessary modules
import sys
import os
sys.path.append('../src')

import yaml
from transformers.ollama_client import OllamaClient

# %%
# Load prompt templates
with open('../config/prompt_templates.yaml', 'r') as f:
    templates = yaml.safe_load(f)

print("Prompt development notebook ready!")
